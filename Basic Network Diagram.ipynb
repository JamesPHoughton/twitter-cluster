# %%
# %pylab inline
import pandas as pd
import cluster_utils as cu
import networkx as nx
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
clustersdf = cu.get_clusters_with_keyword(date='20150618', threshold=5, keyword='charleston')
clustersdf
# Out:
#        date                                           elements  \
# 0  20150618  set([ameshooting, racism, charlestonshooting, ...
# 1  20150618  set([uniteblue, rednationrising, gunsense, tgd...
# 2  20150618  set([hatecrime, dylannroof, walterscott, cleme...
# 3  20150618  set([charlestonchurchshooting, chsnews, emanue...
# 4  20150618  set([latinos, renewus, amemassacre, dylanroof,...
#
#                     id  k-clique     keyword  name  size  threshold
# 0   20150618_k5_t5_i83         5  charleston    83     6          5
# 1   20150618_k4_t5_i15         4  charleston    15    25          5
# 2   20150618_k4_t5_i54         4  charleston    54    13          5
# 3  20150618_k4_t5_i140         4  charleston   140     7          5
# 4    20150618_k3_t5_i4         3  charleston     4   100          5

# %%
# create the network structure
g = nx.Graph()
for i, row in clustersdf[clustersdf['size']<30].iterrows():
    g.add_weighted_edges_from(cu.cluster_post_volume(row).values)

# %%
plt.figure(figsize=(8,8))
nx.draw_networkx(g, pos=nx.spring_layout(g, k=.5), edge_color='grey',alpha=.3)
plt.figtext(.5,.83,'Clusters of Conversation',ha='center', fontsize=14)
plt.box('off')
plt.xticks([])
plt.yticks([]);

# %% [markdown]
# #Do it for a low k

# %%
clustersdf = cu.get_clusters_with_keyword(date='20150618', threshold=5, keyword='charleston')

# create the network structure
g = nx.Graph()
for i, row in clustersdf[clustersdf['k-clique']==5].iterrows():
    g.add_weighted_edges_from(cu.cluster_post_volume(row).values)

# %%
# create the network structure
g = nx.Graph()
for i, row in clustersdf[clustersdf['k-clique']==5].iterrows():
    g.add_weighted_edges_from(cu.cluster_post_volume(row).values)


plt.figure(figsize=(5,5))
nx.draw_networkx(g, pos=nx.spring_layout(g, k=1), edge_color='grey',alpha=.3)
plt.figtext(.5,.83,'5-clique Cluster',ha='center', fontsize=14)
plt.box('off')
plt.xticks([])
plt.yticks([]);

# %%
# create the network structure
g3 = nx.Graph()
for i, row in clustersdf[clustersdf['k-clique']==3].iterrows():
    g3.add_weighted_edges_from(cu.cluster_post_volume(row).values)


plt.figure(figsize=(8,8))
nx.draw_networkx(g3, pos=nx.spring_layout(g3, k=.5), edge_color='grey',alpha=.3)
plt.figtext(.5,.83,'3-clique Cluster',ha='center', fontsize=14)
plt.box('off')
plt.xticks([])
plt.yticks([]);

# %%
plt.figure(figsize=(8,8))
nx.draw_networkx(g, pos=nx.spring_layout(g, k=.15), edge_color='grey',alpha=.3)
plt.figtext(.5,.83,'3-clique Cluster',ha='center', fontsize=14)
plt.box('off')
plt.xticks([])
plt.yticks([]);
